# %%
import pandas as pd

dataset = pd.read_csv("Eartquakes-1990-2023.csv")
dataset.head()
# Out:
#            time                                 place    status  tsunami  \
# 0  631153353990     12 km NNW of Meadow Lakes, Alaska  reviewed        0
# 1  631153491210            14 km S of Volcano, Hawaii  reviewed        0
# 2  631154083450            7 km W of Cobb, California  reviewed        0
# 3  631155512130  11 km E of Mammoth Lakes, California  reviewed        0
# 4  631155824490                16km N of Fillmore, CA  reviewed        0
#
#    significance   data_type  magnitudo        state   longitude   latitude  \
# 0            96  earthquake       2.50       Alaska -149.669200  61.730200
# 1            31  earthquake       1.41       Hawaii -155.212333  19.317667
# 2            19  earthquake       1.11   California -122.806167  38.821000
# 3            15  earthquake       0.98   California -118.846333  37.664333
# 4           134  earthquake       2.95   California -118.934000  34.546000
#
#     depth                              date
# ...

# %%
dataset.dtypes
# Out:
# time              int64
# place            object
# status           object
# tsunami           int64
# significance      int64
# data_type        object
# magnitudo       float64
# state            object
# longitude       float64
# latitude        float64
# depth           float64
# date             object
# dtype: object

# %%
dataset["time"] = pd.to_datetime(dataset.time)

# %%
dataset.dtypes
# Out:
# time            datetime64[ns]
# place                   object
# status                  object
# tsunami                  int64
# significance             int64
# data_type               object
# magnitudo              float64
# state                   object
# longitude              float64
# latitude               float64
# depth                  float64
# date                    object
# dtype: object

# %%
dataset.head()
# Out:
#                            time                                 place  \
# 0 1970-01-01 00:10:31.153353990     12 km NNW of Meadow Lakes, Alaska
# 1 1970-01-01 00:10:31.153491210            14 km S of Volcano, Hawaii
# 2 1970-01-01 00:10:31.154083450            7 km W of Cobb, California
# 3 1970-01-01 00:10:31.155512130  11 km E of Mammoth Lakes, California
# 4 1970-01-01 00:10:31.155824490                16km N of Fillmore, CA
#
#      status  tsunami  significance   data_type  magnitudo        state  \
# 0  reviewed        0            96  earthquake       2.50       Alaska
# 1  reviewed        0            31  earthquake       1.41       Hawaii
# 2  reviewed        0            19  earthquake       1.11   California
# 3  reviewed        0            15  earthquake       0.98   California
# 4  reviewed        0           134  earthquake       2.95   California
#
#     longitude   latitude   depth                              date
# ...

# %%
dataset["status"].unique()
# Out:
# array(['reviewed', 'automatic', 'AUTOMATIC', 'REVIEWED', 'MANUAL',
#        'manual'], dtype=object)

# %%
dataset["status"] = dataset.status.astype("category")

# %%
dataset.dtypes
# Out:
# time            datetime64[ns]
# place                   object
# status                category
# tsunami                  int64
# significance             int64
# data_type               object
# magnitudo              float64
# state                   object
# longitude              float64
# latitude               float64
# depth                  float64
# date                    object
# dtype: object

# %%
dataset["tsunami"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
dataset["tsunami"] = dataset.tsunami.astype("category")

# %%
dataset.dtypes
# Out:
# time            datetime64[ns]
# place                   object
# status                category
# tsunami               category
# significance             int64
# data_type               object
# magnitudo              float64
# state                   object
# longitude              float64
# latitude               float64
# depth                  float64
# date                    object
# dtype: object

# %%
dataset.describe()
# Out:
#                                 time  significance     magnitudo  \
# count                        3445751  3.445751e+06  3.445751e+06
# mean   1970-01-01 00:20:47.123563705  7.400973e+01  1.774076e+00
# min    1970-01-01 00:10:31.153353990  0.000000e+00 -9.990000e+00
# 25%    1970-01-01 00:17:04.401029543  1.300000e+01  9.100000e-01
# 50%    1970-01-01 00:21:22.338053750  3.300000e+01  1.460000e+00
# 75%    1970-01-01 00:25:08.700590235  8.100000e+01  2.300000e+00
# max    1970-01-01 00:28:10.628937884  2.910000e+03  9.100000e+00
# std                              NaN  1.016364e+02  1.291055e+00
#
#           longitude      latitude         depth
# count  3.445751e+06  3.445751e+06  3.445751e+06
# mean  -1.012876e+02  3.746483e+01  2.285387e+01
# min   -1.799997e+02 -8.442200e+01 -1.000000e+01
# 25%   -1.464274e+02  3.406400e+01  3.120000e+00
# 50%   -1.189538e+02  3.793567e+01  7.700000e+00
# 75%   -1.159277e+02  4.784800e+01  1.612000e+01
# ...

# %%
dataset.isnull()
# Out:
#           time  place  status  tsunami  significance  data_type  magnitudo  \
# 0        False  False   False    False         False      False      False
# 1        False  False   False    False         False      False      False
# 2        False  False   False    False         False      False      False
# 3        False  False   False    False         False      False      False
# 4        False  False   False    False         False      False      False
# ...        ...    ...     ...      ...           ...        ...        ...
# 3445746  False  False   False    False         False      False      False
# 3445747  False  False   False    False         False      False      False
# 3445748  False  False   False    False         False      False      False
# 3445749  False  False   False    False         False      False      False
# 3445750  False  False   False    False         False      False      False
#
#          state  longitude  latitude  depth   date
# ...

# %%
dataset.isnull().sum()
# Out:
# time            0
# place           0
# status          0
# tsunami         0
# significance    0
# data_type       0
# magnitudo       0
# state           0
# longitude       0
# latitude        0
# depth           0
# date            0
# dtype: int64

# %%
dataset.duplicated().sum()
# Out:
# 16869

# %%
type_map = {"reviewed" : 0 , "automatic" : 1 , "AUTOMATIC" : 2 , "REVIEWED" : 3 , "MANUAL" : 4 , "manual" : 5}
dataset["encoded_status"] = dataset.status.map(type_map)
dataset.head()
# Out:
#                            time                                 place  \
# 0 1970-01-01 00:10:31.153353990     12 km NNW of Meadow Lakes, Alaska
# 1 1970-01-01 00:10:31.153491210            14 km S of Volcano, Hawaii
# 2 1970-01-01 00:10:31.154083450            7 km W of Cobb, California
# 3 1970-01-01 00:10:31.155512130  11 km E of Mammoth Lakes, California
# 4 1970-01-01 00:10:31.155824490                16km N of Fillmore, CA
#
#      status tsunami  significance   data_type  magnitudo        state  \
# 0  reviewed       0            96  earthquake       2.50       Alaska
# 1  reviewed       0            31  earthquake       1.41       Hawaii
# 2  reviewed       0            19  earthquake       1.11   California
# 3  reviewed       0            15  earthquake       0.98   California
# 4  reviewed       0           134  earthquake       2.95   California
#
#     longitude   latitude   depth                              date  \
# ...

# %%
dataset["data_type"].unique()
# Out:
# array(['earthquake', 'quarry blast', 'explosion', 'other event',
#        'nuclear explosion', 'rock burst', 'ice quake',
#        'chemical explosion', 'sonic boom', 'mine collapse', 'rockslide',
#        'Rock Slide', 'accidental explosion', 'landslide', 'quarry',
#        'mining explosion', 'acoustic noise', 'not reported',
#        'experimental explosion', 'collapse', 'meteorite',
#        'induced or triggered event', 'volcanic eruption', 'Ice Quake',
#        'snow avalanche'], dtype=object)

# %%
type_map_2 = {'earthquake' : 56,
               'quarry blast': 1,
             'explosion' : 2,
             'other event' : 3,
             'nuclear explosion' : 4,
             'rock burst': 5,
             'ice quake':6,
             'chemical explosion': 7,
              'sonic boom' :8,
              'mine collapse':9,
              'rockslide':10,
       'Rock Slide': 11,
              'accidental explosion': 12,
              'landslide': 13,
              'quarry': 14,
       'mining explosion':15,
              'acoustic noise': 16,
              'not reported': 17,
       'experimental explosion': 18,
              'collapse': 19,
              'meteorite':20,
       'induced or triggered event': 21,
              'volcanic eruption': 22,
              'Ice Quake': 23,
       'snow avalanche': 24}

dataset["encoded_data_type"] = dataset.data_type.map(type_map_2)
dataset.head()
# Out:
#                            time                                 place  \
# 0 1970-01-01 00:10:31.153353990     12 km NNW of Meadow Lakes, Alaska
# 1 1970-01-01 00:10:31.153491210            14 km S of Volcano, Hawaii
# 2 1970-01-01 00:10:31.154083450            7 km W of Cobb, California
# 3 1970-01-01 00:10:31.155512130  11 km E of Mammoth Lakes, California
# 4 1970-01-01 00:10:31.155824490                16km N of Fillmore, CA
#
#      status tsunami  significance   data_type  magnitudo        state  \
# 0  reviewed       0            96  earthquake       2.50       Alaska
# 1  reviewed       0            31  earthquake       1.41       Hawaii
# 2  reviewed       0            19  earthquake       1.11   California
# 3  reviewed       0            15  earthquake       0.98   California
# 4  reviewed       0           134  earthquake       2.95   California
#
#     longitude   latitude   depth                              date  \
# ...

# %%
dataset["encoded_data_type"].head()
# Out:
# 0    56
# 1    56
# 2    56
# 3    56
# 4    56
# Name: encoded_data_type, dtype: int64

# %%
dataset.head()
# Out:
#                            time                                 place  \
# 0 1970-01-01 00:10:31.153353990     12 km NNW of Meadow Lakes, Alaska
# 1 1970-01-01 00:10:31.153491210            14 km S of Volcano, Hawaii
# 2 1970-01-01 00:10:31.154083450            7 km W of Cobb, California
# 3 1970-01-01 00:10:31.155512130  11 km E of Mammoth Lakes, California
# 4 1970-01-01 00:10:31.155824490                16km N of Fillmore, CA
#
#      status tsunami  significance   data_type  magnitudo        state  \
# 0  reviewed       0            96  earthquake       2.50       Alaska
# 1  reviewed       0            31  earthquake       1.41       Hawaii
# 2  reviewed       0            19  earthquake       1.11   California
# 3  reviewed       0            15  earthquake       0.98   California
# 4  reviewed       0           134  earthquake       2.95   California
#
#     longitude   latitude   depth                              date  \
# ...

# %%
refined_data = dataset[["time" , "place" , "encoded_status" , "tsunami" , "significance" , "encoded_data_type" ,"magnitudo" , "longitude" , "latitude" , "depth" ,
                       "date"]]
refined_data.head()
# Out:
#                            time                                 place  \
# 0 1970-01-01 00:10:31.153353990     12 km NNW of Meadow Lakes, Alaska
# 1 1970-01-01 00:10:31.153491210            14 km S of Volcano, Hawaii
# 2 1970-01-01 00:10:31.154083450            7 km W of Cobb, California
# 3 1970-01-01 00:10:31.155512130  11 km E of Mammoth Lakes, California
# 4 1970-01-01 00:10:31.155824490                16km N of Fillmore, CA
#
#   encoded_status tsunami  significance  encoded_data_type  magnitudo  \
# 0              0       0            96                 56       2.50
# 1              0       0            31                 56       1.41
# 2              0       0            19                 56       1.11
# 3              0       0            15                 56       0.98
# 4              0       0           134                 56       2.95
#
#     longitude   latitude   depth                              date
# ...

# %% [markdown]
# # DATA VISUALISTION WITH MATPLOTLIB

# %%
import matplotlib.pyplot as plt

# %%
from mpl_toolkits.basemap import Basemap

m = Basemap(projection='mill',llcrnrlat=-80,urcrnrlat=80, llcrnrlon=-180,urcrnrlon=180,lat_ts=20,resolution='c')

longitudes = refined_data["longitude"].tolist()
latitudes = refined_data["latitude"].tolist()
#m = Basemap(width=12000000,height=9000000,projection='lcc',
            #resolution=None,lat_1=80.,lat_2=55,lat_0=80,lon_0=-107.)
x,y = m(longitudes,latitudes)

# %%
fig = plt.figure(figsize=(12,10))
plt.title("All affected areas")
m.plot(x, y, "o", markersize = 2, color = 'blue')
m.drawcoastlines()
m.fillcontinents(color='coral',lake_color='aqua')
m.drawmapboundary()
m.drawcountries()
plt.show()

# %% [markdown]
# ## MODEL CREATION

# %%
from sklearn.model_selection import train_test_split

# Select relevant columns
X = refined_data[['latitude', 'longitude',"depth" ]] #, "significance"]]
y = refined_data['magnitudo']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression

regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score, mean_squared_error

y_pred = regressor.predict(X_test)

r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

print("R^2: {:.2f}, MSE: {:.2f}".format(r2, mse))
# Out:
# R^2: 0.46, MSE: 0.90

# %%
new_data = [[-102.89, -25.40 , 1] , [127.77, -50.42 , 34],[-15 , 61 , 30]] # 6, 43. 96 [-180, 180] , [-90 , 90] , [0, 100]
new_pred = regressor.predict(new_data)
print("New predictions:", new_pred)
# Out:
# New predictions: [4.34703123 0.84450953 3.81212336]
# c:\Users\sksag\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
m = Basemap(projection='mill',llcrnrlat=-80,urcrnrlat=80, llcrnrlon=-180,urcrnrlon=180,lat_ts=20,resolution='c')

longitudes = [-102.89, 127.77, -15]
latitudes = [-25.40 , -50.42 , 61]
x,y = m(longitudes,latitudes)

fig = plt.figure(figsize=(12,10))
plt.title("All affected areas")
m.plot(x, y, "o", markersize = 10, color = 'blue')
m.drawcoastlines()
m.fillcontinents(color='coral',lake_color='aqua')
m.drawmapboundary()
m.drawcountries()
plt.show()

# %%
new_data_string = ["102.89 S 25.40 W" , "127.77 N 50.42 W" , "-15 N 61 E" ]

plt.bar(new_data_string, new_pred)
plt.show()
